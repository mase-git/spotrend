# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Data cleaning phase refers to the techniques and steps that are used to prepare raw data for analysis. It is a crucial step in the data analysis process because it helps ensure that the data is clean, consistent, and ready for further analysis.
#
# Data cleaning involves a variety of tasks, such as cleaning the data to remove errors or inconsistencies, handling missing values, normalizing or scaling the data, and transforming the data into a suitable format for analysis. These tasks are necessary because raw data is often messy and unstructured, and may contain a wide range of errors or inconsistencies that can affect the accuracy and reliability of the analysis

# %% [markdown]
# ## Setup Environment

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as  sns
import pickle

# %% [markdown]
# ## Import Data

# %%
## Import Data

# Warning: Run the data_exploration.ipynb to generate the explored_spotify_data.csv
df = pd.read_csv('../data/explored_spotify_data.csv')
df = df.drop(columns=['Unnamed: 0'], axis=1)
df.head(4)
# Out:
#    disc_number  duration_ms  explicit                track_id  is_local  \
# 0            1       239359      True  1bDbXMyjaUIooNwFE9wn0N     False
# 1            1       198973      True  6DCZcSspjsKoFjzjrWoCdn     False
# 2            1       160821      True  7l2nxyx7IkBX5orhkALg0V     False
# 3            1       218364      True  3F5CgOj3wFlRv51JsHbxhe     False
#
#                       track_name  popularity  track_number track_type  \
# 0                      Rich Flex          96             1      track
# 1                     God's Plan          85             5      track
# 2             Privileged Rappers          83             5      track
# 3  Jimmy Cooks (feat. 21 Savage)          90            14      track
#
#                 artist_id  ... loudness mode speechiness acousticness  \
# 0  3TVXtAsR1Inumwj472S9r4  ...   -9.342    0       0.244     0.050300
# 1  3TVXtAsR1Inumwj472S9r4  ...   -9.211    1       0.109     0.033200
# 2  3TVXtAsR1Inumwj472S9r4  ...   -7.384    1       0.198     0.002740
# 3  3TVXtAsR1Inumwj472S9r4  ...   -4.711    1       0.175     0.000307
#
#   instrumentalness liveness valence    tempo   features_type  time_signature
# 0         0.000002    0.355   0.424  153.150  audio_features               3
# 1         0.000083    0.552   0.357   77.169  audio_features               4
# 2         0.000000    0.123   0.616  144.045  audio_features               4
# 3         0.000002    0.093   0.366  165.921  audio_features               4
#
# [4 rows x 32 columns]

# %% [markdown]
# ## Check constants columns

# %% [markdown]
# During the data exploration, we didn't analyze the behaviour of data. If we want to have a consistent and high quality dataset, we need to remove every attribute with no information inside. In other words, we should delete columns without any variation of data or with single-element domain.

# %%
for col in df.columns:
    if len(df[col].value_counts()) == 1:
        print(f'{col} => {df[col][0]}')
# Out:
# is_local => False
# track_type => track
# artist_type => artist
# album_type.1 => album
# features_type => audio_features

# %%
# values inside the previous column determinate the nature of the subset of data inside the merged dataset. 
# They aren't actually useful, so, we can delete them.
df = df.drop(columns=['is_local', 'track_type', 'artist_type', 'album_type.1', 'album_type', 'features_type'])
df.head(5)
# Out:
#    disc_number  duration_ms  explicit                track_id  \
# 0            1       239359      True  1bDbXMyjaUIooNwFE9wn0N
# 1            1       198973      True  6DCZcSspjsKoFjzjrWoCdn
# 2            1       160821      True  7l2nxyx7IkBX5orhkALg0V
# 3            1       218364      True  3F5CgOj3wFlRv51JsHbxhe
# 4            1       189893      True  59nOXPmaKlBfGMDeOVGrIK
#
#                         track_name  popularity  track_number  \
# 0                        Rich Flex          96             1
# 1                       God's Plan          85             5
# 2               Privileged Rappers          83             5
# 3    Jimmy Cooks (feat. 21 Savage)          90            14
# 4  WAIT FOR U (feat. Drake & Tems)          88             7
#
#                 artist_id artist_name                album_id  ... key  \
# 0  3TVXtAsR1Inumwj472S9r4       Drake  5MS3MvWHJ3lOZPLiMxzOU6  ...  11
# 1  3TVXtAsR1Inumwj472S9r4       Drake  1ATL5GLyefJaxhQzSPVrLX  ...   7
# 2  3TVXtAsR1Inumwj472S9r4       Drake  5MS3MvWHJ3lOZPLiMxzOU6  ...   5
# 3  3TVXtAsR1Inumwj472S9r4       Drake  3cf4iSSKd8ffTncbtKljXw  ...   0
# 4  3TVXtAsR1Inumwj472S9r4       Drake  6tE9Dnp2zInFij4jKssysL  ...   1
#
#   loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   -9.342    0        0.244      0.050300          0.000002    0.3550
# 1   -9.211    1        0.109      0.033200          0.000083    0.5520
# 2   -7.384    1        0.198      0.002740          0.000000    0.1230
# 3   -4.711    1        0.175      0.000307          0.000002    0.0930
# 4   -4.474    1        0.340      0.314000          0.000000    0.0686
#
#    valence    tempo  time_signature
# 0    0.424  153.150               3
# 1    0.357   77.169               4
# 2    0.616  144.045               4
# 3    0.366  165.921               4
# 4    0.339   83.389               4
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39863 entries, 0 to 39862
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   disc_number             39863 non-null  int64
#  1   duration_ms             39863 non-null  int64
#  2   explicit                39863 non-null  bool
#  3   track_id                39863 non-null  object
#  4   track_name              39863 non-null  object
#  5   popularity              39863 non-null  int64
#  6   track_number            39863 non-null  int64
#  7   artist_id               39863 non-null  object
#  8   artist_name             39863 non-null  object
#  9   album_id                39863 non-null  object
#  10  album_name              39863 non-null  object
#  11  release_date            39863 non-null  object
#  12  release_date_precision  39863 non-null  object
#  13  total_tracks            39863 non-null  int64
#  14  danceability            39863 non-null  float64
#  15  energy                  39863 non-null  float64
#  16  key                     39863 non-null  int64
#  17  loudness                39863 non-null  float64
#  18  mode                    39863 non-null  int64
#  19  speechiness             39863 non-null  float64
#  20  acousticness            39863 non-null  float64
#  21  instrumentalness        39863 non-null  float64
#  22  liveness                39863 non-null  float64
#  23  valence                 39863 non-null  float64
#  24  tempo                   39863 non-null  float64
#  25  time_signature          39863 non-null  int64
# dtypes: bool(1), float64(9), int64(8), object(8)
# memory usage: 7.6+ MB

# %% [markdown]
# ## Remove subset id attributes

# %%
# the references of single subset of data such as artists, album and features id are useless in the merged dataset
df = df.drop(columns=['artist_id', 'album_id'], axis=1)
df.head(5)
# Out:
#    disc_number  duration_ms  explicit                track_id  \
# 0            1       239359      True  1bDbXMyjaUIooNwFE9wn0N
# 1            1       198973      True  6DCZcSspjsKoFjzjrWoCdn
# 2            1       160821      True  7l2nxyx7IkBX5orhkALg0V
# 3            1       218364      True  3F5CgOj3wFlRv51JsHbxhe
# 4            1       189893      True  59nOXPmaKlBfGMDeOVGrIK
#
#                         track_name  popularity  track_number artist_name  \
# 0                        Rich Flex          96             1       Drake
# 1                       God's Plan          85             5       Drake
# 2               Privileged Rappers          83             5       Drake
# 3    Jimmy Cooks (feat. 21 Savage)          90            14       Drake
# 4  WAIT FOR U (feat. Drake & Tems)          88             7       Drake
#
#             album_name release_date  ... key  loudness  mode  speechiness  \
# 0             Her Loss   2022-11-04  ...  11    -9.342     0        0.244
# 1             Scorpion   2018-06-29  ...   7    -9.211     1        0.109
# 2             Her Loss   2022-11-04  ...   5    -7.384     1        0.198
# 3  Honestly, Nevermind   2022-06-17  ...   0    -4.711     1        0.175
# 4    I NEVER LIKED YOU   2022-04-29  ...   1    -4.474     1        0.340
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0      0.050300          0.000002    0.3550    0.424  153.150               3
# 1      0.033200          0.000083    0.5520    0.357   77.169               4
# 2      0.002740          0.000000    0.1230    0.616  144.045               4
# 3      0.000307          0.000002    0.0930    0.366  165.921               4
# 4      0.314000          0.000000    0.0686    0.339   83.389               4
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Changing boolean variables in integer

# %%
# the only boolean variable is explicit
df.explicit = df.explicit.astype(int)
df.head(2)
# Out:
#    disc_number  duration_ms  explicit                track_id  track_name  \
# 0            1       239359         1  1bDbXMyjaUIooNwFE9wn0N   Rich Flex
# 1            1       198973         1  6DCZcSspjsKoFjzjrWoCdn  God's Plan
#
#    popularity  track_number artist_name album_name release_date  ... key  \
# 0          96             1       Drake   Her Loss   2022-11-04  ...  11
# 1          85             5       Drake   Scorpion   2018-06-29  ...   7
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -9.342     0        0.244        0.0503          0.000002     0.355
# 1    -9.211     1        0.109        0.0332          0.000083     0.552
#
#    valence    tempo  time_signature
# 0    0.424  153.150               3
# 1    0.357   77.169               4
#
# [2 rows x 24 columns]

# %% [markdown]
# ## Export result dataset

# %%
df.to_csv('../data/cleaned_spotify_data.csv')
