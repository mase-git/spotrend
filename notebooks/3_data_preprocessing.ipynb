# %% [markdown]
# # Data Preprocessinng

# %% [markdown]
# During this step, the data may be transformed or manipulated in order to prepare it for further analysis or modeling. This may include creating new features, aggregating data, or selecting a subset of the data.

# %% [markdown]
# ## Setup Environment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as  sns
import pickle

# %% [markdown]
# ## Import Data

# %%
## Import Data

# Warning: Run the data_exploration.ipynb to generate the explored_spotify_data.csv
df = pd.read_csv('../data/explored_spotify_data.csv')
df = df.drop(columns=['Unnamed: 0'], axis=1)
df.head(4)
# Out:
#    disc_number  explicit                track_id  \
# 0            1         1  1bDbXMyjaUIooNwFE9wn0N
# 1            1         1  6DCZcSspjsKoFjzjrWoCdn
# 2            1         1  7l2nxyx7IkBX5orhkALg0V
# 3            1         1  3F5CgOj3wFlRv51JsHbxhe
#
#                       track_name  popularity  track_number artist_name  \
# 0                      Rich Flex          96             1       Drake
# 1                     God's Plan          85             5       Drake
# 2             Privileged Rappers          83             5       Drake
# 3  Jimmy Cooks (feat. 21 Savage)          90            14       Drake
#
#             album_name  total_tracks  danceability  ...  mode  speechiness  \
# 0             Her Loss            16         0.561  ...     0        0.244
# 1             Scorpion            25         0.754  ...     1        0.109
# 2             Her Loss            16         0.934  ...     1        0.198
# ...

# %% [markdown]
# ## Define Artist Popularity

# %%
df = df.rename(columns={'popularity' : 'track_popularity'})
list(df.columns)
# Out:
# ['disc_number',
#  'explicit',
#  'track_id',
#  'track_name',
#  'track_popularity',
#  'track_number',
#  'artist_name',
#  'album_name',
#  'total_tracks',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'duration_min',
#  'release_year']

# %%
artists = set(list(df['artist_name']))
df_mean_artist = df.groupby('artist_name').apply(lambda x : x.mean())
df_artist_popularity = df_mean_artist[['track_popularity']]
df_artist_popularity.rename(columns={'track_popularity' : 'artist_popularity'})
df_artist_popularity.head()
# Out:
# /var/folders/jd/ysm594m928dfp92zgrlsp1vr0000gn/T/ipykernel_28769/2033010382.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mean_artist = df.groupby('artist_name').apply(lambda x : x.mean())
#              track_popularity
# artist_name
# $NOT                59.318182
# $uicideboy$         70.500000
# (G)I-DLE            57.600000
# *NSYNC              49.744681
# 2 Chainz            54.432432

# %%
df = pd.merge(df, df_artist_popularity, on='artist_name', how='left')
df = df.rename(columns={'track_popularity_y' : 'artist_popularity', 'track_popularity_x' : 'track_popularity'})
df.head(5)
# Out:
#    disc_number  explicit                track_id  \
# 0            1         1  1bDbXMyjaUIooNwFE9wn0N
# 1            1         1  6DCZcSspjsKoFjzjrWoCdn
# 2            1         1  7l2nxyx7IkBX5orhkALg0V
# 3            1         1  3F5CgOj3wFlRv51JsHbxhe
# 4            1         1  59nOXPmaKlBfGMDeOVGrIK
#
#                         track_name  track_popularity  track_number  \
# 0                        Rich Flex                96             1
# 1                       God's Plan                85             5
# 2               Privileged Rappers                83             5
# 3    Jimmy Cooks (feat. 21 Savage)                90            14
# 4  WAIT FOR U (feat. Drake & Tems)                88             7
#
#   artist_name           album_name  total_tracks  danceability  ...  \
# 0       Drake             Her Loss            16         0.561  ...
# 1       Drake             Scorpion            25         0.754  ...
# ...

# %%
df.head(1)
# Out:
#    disc_number  explicit                track_id track_name  track_popularity  \
# 0            1         1  1bDbXMyjaUIooNwFE9wn0N  Rich Flex                96
#
#    track_number artist_name album_name  total_tracks  danceability  ...  \
# 0             1       Drake   Her Loss            16         0.561  ...
#
#    speechiness  acousticness  instrumentalness  liveness  valence   tempo  \
# 0        0.244        0.0503          0.000002     0.355    0.424  153.15
#
#    time_signature  duration_min  release_year  artist_popularity
# 0               3          3.99          2022              76.94
#
# [1 rows x 24 columns]
